# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Load your dataset (adjust the path as needed)
file_path = '/content/drive/MyDrive/Colab Notebooks/HACKATHON_TRAINING_DATA.CSV'
df = pd.read_csv(file_path)

# Print column names
print(df.columns.tolist())
# Out:
# Mounted at /content/drive
# ...

# %%
df
# Out:
#         ACCT_AGE      LIMIT        OUTS  ACCT_RESIDUAL_TENURE  LOAN_TENURE  \
# 0          1.613  1005500.0   494161.89                 0.890          914
# 1          1.783  1005500.0   428072.24                 0.720          914
# 2          1.698  1005500.0   461364.10                 0.805          914
# 3          9.127  1005500.0  1204287.25                17.878         9862
# 4          9.296  1005500.0  1203224.25                17.708         9862
# ...          ...        ...         ...                   ...          ...
# 327736    11.837   185161.0   166393.79                 4.411         5934
# 327737     2.516   735500.0   529552.88                 3.486         2192
# 327738     2.944   705500.0   849950.35                13.059         5844
# 327739     1.021   205500.0   169529.00                 1.980         1096
# 327740    10.397  1005500.0   848538.22                 7.525         6545
#
#         INSTALAMT SI_FLG     AGE  VINTAGE  KYC_SCR  ...  \
# ...

# %%
df.head()
# Out:
#    ACCT_AGE      LIMIT        OUTS  ACCT_RESIDUAL_TENURE  LOAN_TENURE  \
# 0     1.613  1005500.0   494161.89                 0.890          914
# 1     1.783  1005500.0   428072.24                 0.720          914
# 2     1.698  1005500.0   461364.10                 0.805          914
# 3     9.127  1005500.0  1204287.25                17.878         9862
# 4     9.296  1005500.0  1203224.25                17.708         9862
#
#    INSTALAMT SI_FLG     AGE  VINTAGE  KYC_SCR  ... CREDIT_HISTORY_LENGTH1  \
# 0    38513.0      Y  57.663   18.601    110.0  ...              7yrs 6mon
# 1    38513.0      Y  57.833   18.771    110.0  ...              7yrs 6mon
# 2    38513.0      Y  57.748   18.686    110.0  ...              7yrs 6mon
# 3    12736.0      Y  52.302   14.039    110.0  ...             10yrs 8mon
# 4    12736.0      Y  52.472   14.209    110.0  ...             10yrs 8mon
#
#   NO_OF_INQUIRIES1 INCOME_BAND1           AGREG_GROUP   PRODUCT_TYPE  \
# ...

# %%
print(df['TARGET'].value_counts(normalize=True))

# Nulls overview
print(df.isnull().sum().sort_values(ascending=False).head(20))

# Column types
print(df.dtypes)
# Out:
# TARGET
# 0    0.891866
# 1    0.108134
# Name: proportion, dtype: float64
# LAST_1_YR_RG4           303363
# LAST_3_YR_RG4           267761
# CUST_NO_OF_TIMES_NPA    215669
# FIRST_NPA_TENURE        215669
# LATEST_NPA_TENURE       215669
# NO_YRS_NPA              215669
# NO_ENQ                  167955
# CRIFF_33                 60540
# CRIFF_44                 60380
# CRIFF_22                 60174
# SIXMNTHOUTSTANGBAL       31064
# SIXMNTHSCR               31064
# SIXMNTHSDR               31064
# SIXMNTHAVGYTD            31064
# SIXMNTHAVGMTD            31064
# SIXMNTHAVGQTD            31064
# FIVEMNTHAVGYTD           30826
# FIVEMNTHSDR              30826
# FIVEMNTHAVGQTD           30826
# FIVEMNTHAVGMTD           30826
# dtype: int64
# ACCT_AGE                float64
# LIMIT                   float64
# OUTS                    float64
# ACCT_RESIDUAL_TENURE    float64
# LOAN_TENURE               int64
#                          ...
# LATEST_CR_DAYS          float64
# ...

# %%
# 1. Set the missing value threshold
threshold = 0.6  # Drop columns with more than 60% missing values

# 2. Get % of missing values
missing_percent = df.isnull().mean()

# 3. Filter columns to drop
cols_to_drop = missing_percent[missing_percent > threshold].index.tolist()

# 4. Drop them
df_cleaned = df.drop(columns=cols_to_drop)

print(f"Dropped {len(cols_to_drop)} columns due to high missingness.")
# Out:
# Dropped 6 columns due to high missingness.

# %%
missing_summary = df_cleaned.isnull().sum()
missing_summary = missing_summary[missing_summary > 0].sort_values(ascending=False)
print(missing_summary)
# Out:
# NO_ENQ        167955
# CRIFF_33       60540
# CRIFF_44       60380
# CRIFF_22       60174
# SIXMNTHSCR     31064
#                ...
# VINTAGE            2
# INB_FLG            2
# UID_FLG            2
# EKYC_FLG           2
# POP_CODE           2
# Length: 111, dtype: int64

# %%
# Step 2B: Imputation

# Separate columns by type
num_cols = df_cleaned.select_dtypes(include=['float64', 'int64']).columns
cat_cols = df_cleaned.select_dtypes(include='object').columns

# Impute numerical columns with median
for col in num_cols:
    if df_cleaned[col].isnull().sum() > 0:
        median_value = df_cleaned[col].median()
        df_cleaned[col].fillna(median_value, inplace=True)

# Impute categorical columns with mode
for col in cat_cols:
    if df_cleaned[col].isnull().sum() > 0:
        mode_value = df_cleaned[col].mode()[0]
        df_cleaned[col].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-2780280750.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned[col].fillna(median_value, inplace=True)
# /tmp/ipython-input-2780280750.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Make sure no missing values remain
print("Remaining missing values:", df_cleaned.isnull().sum().sum())  # Should be 0
# Out:
# Remaining missing values: 0

# %%
# Standardize the format (e.g., "NOV24" -> "2024-11")
import datetime

def convert_time_period(x):
    try:
        return datetime.datetime.strptime(x, "%b%y")
    except:
        return pd.NaT

df_cleaned['TIME_PERIOD_DT'] = df_cleaned['TIME_PERIOD'].apply(convert_time_period)
df_cleaned['MONTH'] = df_cleaned['TIME_PERIOD_DT'].dt.month
df_cleaned['YEAR'] = df_cleaned['TIME_PERIOD_DT'].dt.year

# %%
# Add new columns
df_cleaned['UTILIZATION_RATIO'] = df_cleaned['OUTS'] / df_cleaned['LIMIT']
df_cleaned['INSTALAMT_TO_LIMIT'] = df_cleaned['INSTALAMT'] / df_cleaned['LIMIT']
df_cleaned['RESIDUAL_RATIO'] = df_cleaned['ACCT_RESIDUAL_TENURE'] / df_cleaned['LOAN_TENURE']

# %%
# Convert all "Y"/"N" flag columns
flag_cols = [col for col in df_cleaned.columns if df_cleaned[col].nunique() == 2 and
             set(df_cleaned[col].dropna().unique()).issubset({'Y', 'N'})]

for col in flag_cols:
    df_cleaned[col] = df_cleaned[col].map({'Y': 1, 'N': 0})

# %%
import re

def parse_credit_history(val):
    if isinstance(val, str):
        match = re.match(r"(\d+)yrs\s*(\d+)?mon?", val)
        if match:
            years = int(match.group(1))
            months = int(match.group(2)) if match.group(2) else 0
            return years * 12 + months
    return np.nan

df_cleaned['CREDIT_HISTORY_MONTHS'] = df_cleaned['CREDIT_HISTORY_LENGTH1'].apply(parse_credit_history)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Only numeric features + target
numeric_cols = df_cleaned.select_dtypes(include=[np.number]).columns.tolist()
correlation_matrix = df_cleaned[numeric_cols].corr()

# Correlation with TARGET only
target_corr = correlation_matrix['TARGET'].sort_values(key=abs, ascending=False)

print("Top correlated features with TARGET:")
print(target_corr.head(15))  # Top 15

# Plot top ones
plt.figure(figsize=(10, 6))
sns.barplot(x=target_corr.head(15).values, y=target_corr.head(15).index)
plt.title('Top 15 Correlated Features with TARGET')
plt.xlabel('Correlation')
plt.tight_layout()
plt.show()
# Out:
# Top correlated features with TARGET:
# TARGET                    1.000000
# CRIFF_11                 -0.202403
# TIMES_IRAC_SLIP          -0.181195
# TIMES_IRAC_UPR           -0.161919
# CRIFF_22                 -0.145228
# LOAN_TENURE              -0.140353
# NO_YRS_RG3               -0.135230
# LAST_1_YR_RG2            -0.134234
# ACCT_AGE                 -0.124073
# LAST_1_YR_RG3            -0.121240
# INSTALAMT_TO_LIMIT        0.117200
# CREDIT_HISTORY_MONTHS    -0.117142
# TOT_IRAC_CHNG            -0.116612
# LATEST_CR_DAYS            0.115355
# OLDEST_RESIDUAL_TENURE   -0.114637
# Name: TARGET, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

# Prep the data
# Exclude TARGET, UNIQUE_ID, and the TIME_PERIOD_DT column
X = df_cleaned.drop(['TARGET', 'UNIQUE_ID', 'TIME_PERIOD_DT'], axis=1)
y = df_cleaned['TARGET']

# Handle any remaining non-numeric columns via basic encoding
X = pd.get_dummies(X, drop_first=True)

# Fill NA temporarily (simple imputation for now)
X.fillna(-999, inplace=True)

# Split the dataset
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# Train the model
xgb = XGBClassifier(n_estimators=100, use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb.fit(X_train, y_train)

# Feature importance
importances = pd.Series(xgb.feature_importances_, index=X.columns)
importances = importances.sort_values(ascending=False)

# Display top 15 important features
print("Top 15 important features:")
print(importances.head(15))

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=importances.head(15).values, y=importances.head(15).index)
plt.title('Top 15 Feature Importances (XGBoost)')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [09:53:06] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Top 15 important features:
# AGREG_GROUP_#Total Xpress Credit    0.127009
# LAST_1_YR_RG2                       0.117509
# CRIFF_11                            0.045152
# CRIFF_55                            0.028231
# ONEMNTHCR                           0.021635
# TIMES_IRAC_SLIP                     0.016107
# LATEST_CR_DAYS                      0.015147
# CRIFF_66                            0.014268
# ONEMNTHOUTSTANGBAL                  0.014191
# ALL_LON_MAX_IRAC                    0.013273
# ALL_LON_OUTS                        0.010888
# LATEST_DR_DAYS                      0.009788
# CRIFF_33                            0.009603
# CRIFF_22                            0.009518
# PRI_OVERDUE_ACCTS1                  0.008042
# dtype: float32

# %%
from sklearn.preprocessing import LabelEncoder

# Label encode binary categorical columns
binary_cols = ['SI_FLG', 'INB_FLG', 'UID_FLG', 'EKYC_FLG']
le = LabelEncoder()
for col in binary_cols:
    df_cleaned[col] = le.fit_transform(df_cleaned[col].astype(str))

# One-hot encode multi-class categorical columns
multi_cat_cols = ['PRODUCT_TYPE', 'AGREG_GROUP']
df_cleaned = pd.get_dummies(df_cleaned, columns=multi_cat_cols, drop_first=True)

# %%
# Step 4b: Encode categorical columns properly
from sklearn.preprocessing import LabelEncoder

# 🔍 Identify object-type (string) columns
cat_cols = df_cleaned.select_dtypes(include=['object']).columns.tolist()
print("Categorical columns to encode:", cat_cols)

# ✅ NEW: Encode each categorical column using LabelEncoder
le = LabelEncoder()
for col in cat_cols:
    df_cleaned[col] = le.fit_transform(df_cleaned[col].astype(str))

print("Encoding complete.")
# Out:
# Categorical columns to encode: ['KYC_FLG', 'AVERAGE_ACCT_AGE1', 'CREDIT_HISTORY_LENGTH1', 'INCOME_BAND1', 'TIME_PERIOD']
# Encoding complete.

# %%
X = df_cleaned.drop(columns=['TARGET', 'UNIQUE_ID', 'TIME_PERIOD'])  # input features
y = df_cleaned['TARGET']  # target variable

# %%
X.shape
# Out:
# (327741, 141)

# %%
df.shape
# Out:
# (327741, 139)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import pandas as pd # Make sure pandas is imported if not already

# Re-create X and y
# Drop columns that should not be features, including the original time columns
# Use errors='ignore' in drop just in case the column was already removed by get_dummies
X = df_cleaned.drop(columns=['TARGET', 'UNIQUE_ID', 'TIME_PERIOD', 'TIME_PERIOD_DT'], errors='ignore')
y = df_cleaned['TARGET']

# Identify and drop any remaining non-numeric columns just before splitting
# This is a failsafe to catch any datetime or object columns that might still be present
non_numeric_cols = X.select_dtypes(exclude=['number']).columns
if len(non_numeric_cols) > 0:
    print(f"Dropping non-numeric columns from X: {list(non_numeric_cols)}")
    X = X.drop(columns=non_numeric_cols)
# Out:
# Dropping non-numeric columns from X: ['PRODUCT_TYPE_EDUCATION LOAN', 'PRODUCT_TYPE_HOME LOAN', 'PRODUCT_TYPE_PERSONAL LOAN', 'AGREG_GROUP_#Housing Loan', 'AGREG_GROUP_#Total Auto Loan', 'AGREG_GROUP_#Total Xpress Credit']

# %%
X.shape
# Out:
# (327741, 134)

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, f1_score

# Calculate scale_pos_weight
neg = sum(y_train == 0)
pos = sum(y_train == 1)
scale = neg / pos

# Baseline XGBoost
xgb = XGBClassifier(
    random_state=42,
    scale_pos_weight=scale,        # Compensate for class imbalance
    use_label_encoder=False,
    eval_metric='logloss'          # Prevents warning
)

# Train
xgb.fit(X_train, y_train)

# Predict
y_pred = xgb.predict(X_test)
y_proba = xgb.predict_proba(X_test)[:, 1]

# Evaluation
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nROC AUC Score:", roc_auc_score(y_test, y_proba))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [09:54:41] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Confusion Matrix:
# [[49961  8500]
#  [ 1248  5840]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91     58461
#            1       0.41      0.82      0.55      7088
#
#     accuracy                           0.85     65549
#    macro avg       0.69      0.84      0.73     65549
# weighted avg       0.91      0.85      0.87     65549
#
#
# ROC AUC Score: 0.920265727546249
# F1 Score: 0.5450812021653911

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, f1_score
import numpy as np

# Calculate scale_pos_weight
neg = sum(y_train == 0)
pos = sum(y_train == 1)
scale = neg / pos

# Baseline XGBoost
xgb = XGBClassifier(
    random_state=42,
    scale_pos_weight=scale,        # Compensate for class imbalance
    use_label_encoder=False,
    eval_metric='logloss'          # Prevents warning
)

# Train
xgb.fit(X_train, y_train)

# Predict probabilities
y_proba = xgb.predict_proba(X_test)[:, 1]

# Threshold tuning
thresholds = np.arange(0.0, 1.01, 0.01)
f1_scores = []

for thresh in thresholds:
    y_pred_thresh = (y_proba >= thresh).astype(int)
    score = f1_score(y_test, y_pred_thresh)
    f1_scores.append(score)

# Best threshold
best_thresh = thresholds[np.argmax(f1_scores)]
best_f1 = max(f1_scores)

print(f"\nBest Threshold: {best_thresh:.2f}")
print(f"Best F1 Score: {best_f1:.4f}")

# Final predictions with best threshold
y_pred_best = (y_proba >= best_thresh).astype(int)

# Evaluation
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_best))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_best))

print("\nROC AUC Score:", roc_auc_score(y_test, y_proba))
print("F1 Score at Best Threshold:", f1_score(y_test, y_pred_best))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [09:55:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Threshold: 0.75
# Best F1 Score: 0.5971
#
# Confusion Matrix:
# [[54933  3528]
#  [ 2570  4518]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95     58461
#            1       0.56      0.64      0.60      7088
#
#     accuracy                           0.91     65549
#    macro avg       0.76      0.79      0.77     65549
# weighted avg       0.91      0.91      0.91     65549
#
#
# ROC AUC Score: 0.920265727546249
# F1 Score at Best Threshold: 0.5970662085370688

# %%
param_dist = {
    'n_estimators': [100, 300, 500],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 1, 5],
    'reg_alpha': [0, 0.5, 1],
    'reg_lambda': [1, 2, 5]
}

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, f1_score

# Base model with fixed scale_pos_weight
xgb_base = XGBClassifier(
    scale_pos_weight=scale,
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)

# F1 Scorer
f1 = make_scorer(f1_score)

# Randomized Search
random_search = RandomizedSearchCV(
    estimator=xgb_base,
    param_distributions=param_dist,
    scoring=f1,
    n_iter=20,
    cv=3,
    verbose=1,
    random_state=42,
    n_jobs=-1
)

# Fit search
random_search.fit(X_train, y_train)

# Best model
best_model = random_search.best_estimator_
print("Best Params:", random_search.best_params_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [10:42:09] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Params: {'subsample': 0.8, 'reg_lambda': 5, 'reg_alpha': 0.5, 'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.05, 'gamma': 1, 'colsample_bytree': 1.0}

# %%
xgb_best = XGBClassifier(
    random_state=42,
    scale_pos_weight=scale,     # still useful
    use_label_encoder=False,
    eval_metric='logloss',
    subsample=0.8,
    reg_lambda=5,
    reg_alpha=0.5,
    n_estimators=500,
    max_depth=7,
    learning_rate=0.05,
    gamma=1,
    colsample_bytree=1.0
)

# %%
xgb_best.fit(X_train, y_train)

# Predict probabilities on test set
y_proba = xgb_best.predict_proba(X_test)[:, 1]

# Threshold tuning
thresholds = np.arange(0.0, 1.01, 0.01)
f1_scores = []

for thresh in thresholds:
    y_pred_thresh = (y_proba >= thresh).astype(int)
    f1_scores.append(f1_score(y_test, y_pred_thresh))

best_thresh = thresholds[np.argmax(f1_scores)]
best_f1 = max(f1_scores)

print(f"\nBest Threshold: {best_thresh:.2f}")
print(f"Best F1 Score: {best_f1:.4f}")

# Final predictions
y_pred_best = (y_proba >= best_thresh).astype(int)

# Evaluate
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_best))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_best))

print("\nROC AUC Score:", roc_auc_score(y_test, y_proba))
print("F1 Score at Best Threshold:", f1_score(y_test, y_pred_best))
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [10:52:24] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best Threshold: 0.70
# Best F1 Score: 0.6113
#
# Confusion Matrix:
# [[54642  3819]
#  [ 2287  4801]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.95     58461
#            1       0.56      0.68      0.61      7088
#
#     accuracy                           0.91     65549
#    macro avg       0.76      0.81      0.78     65549
# weighted avg       0.92      0.91      0.91     65549
#
#
# ROC AUC Score: 0.9253344211106684
# F1 Score at Best Threshold: 0.6112808759867583

# %%
import joblib

# Save the model
joblib.dump(xgb_best, 'xgb_best_model.pkl')
# Out:
# ['xgb_best_model.pkl']

# %%
joblib.dump(xgb_best, '/content/drive/MyDrive/Colab Notebooks/xgb_best_model.pkl')
# Out:
# ['/content/drive/MyDrive/Colab Notebooks/xgb_best_model.pkl']

# %%
from google.colab import files
files.download('xgb_best_model.pkl')
